# %%
#import needed libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# from selenium import webdriver
# from selenium.webdriver.chrome.options import Options

# %%
# options = Options()
# chrome_path = '/Users/davidwalkup/Downloads/chromedriver'
# driver = webdriver.Chrome(chrome_path, 
#                           options=options)

# %%
#generate list of years for use in loop
year_list = [year for year in range(2010, 2015)]
year_list
# Out:
# [2010, 2011, 2012, 2013, 2014]

# %%
#website URL to be scraped
url = 'https://www.imdb.com/search/title/?year=2010-01-01,2010-12-31&sort=boxoffice_gross_us,desc&view=advanced'
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text)

# %%
for count, div in enumerate(soup.findAll('div')):
    print('***',count,'***',div)
# Out:
# *** 0 *** <div id="92eb3052-4444-40a4-a919-3e4e670d02dd">
# ...

# %%
#find collection of movie data
movie_info_raw = soup.findAll('div')[46]

# %%
#find the movie's name
movie_info_raw.findAll('h3')[0].findAll('a')[0].contents[0]
# Out:
# 'Toy Story 3'

# %%
#find the movie's MPAA rating
movie_info_raw.findAll('p')[0].findAll('span')[0].contents[0]
# Out:
# 'G'

# %%
#find the movie's genre
str(movie_info_raw.findAll('p')[0].findAll('span')[4].contents[0]).strip()
# Out:
# 'Action, Adventure, Sci-Fi'

# %%
#find the movie's gross box office (in millions)
float(str(movie_info_raw.findAll('p')[3].findAll('span')[4].contents[0]).strip().replace('$','').replace('M', ''))
# Out:
# 415.0

# %%
movie_info = {}

for i in range(1,len(table_items)):
    movie_title = table_items[i].findAll('td')[1].a.contents[0]
    movie_gross = int(table_items[i].findAll('td')[6].contents[0].replace(',', '').replace('$', ''))
    movie_info[i] = {'title': movie_title, 'gross' : movie_gross, 'year' : 2010}
movie_info

# %%
df_2010 = pd.DataFrame.from_dict(movie_info, orient='index')
df_2010.index.name = 'Movie Rank'
df_2010.columns = ['Movie Title', 'Dom Gross Box Office', 'Year']
df_2010.head()

# %%
raw_movie_link = table_items[1].findAll('a')[0]
raw_movie_link

# %%
str(table_items[235].findAll('a')[0])[32:]
