# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def get_keys(path):
    with open(path) as f:
        return json.load(f)

api_keys = get_keys("/Users/carsonlloyd/.secret/api_keys.json")

ds_key_1 = list(api_keys.values())[0]

# %%
ds_key_1
# Out:
# '3d7f6e4c06d215c255637e7c68040113'

# %%
r = requests.get("https://api.themoviedb.org/3/discover/movie?api_key=3d7f6e4c06d215c255637e7c68040113&language=en-US&sort_by=revenue.desc&include_adult=false&include_video=false&page=1&primary_release_year=2018")

# %%
r.json()
# Out:
# {'status_code': 25,
#  'status_message': 'Your request count (41) is over the allowed limit of 40.'}

# %%
url = 'https://www.imdb.com/search/title/?year=2019&title_type=feature&sort=boxoffice_gross_us,desc'
res = requests.get(url)

# %%
print(res.raise_for_status())
soup = BeautifulSoup(res.text)
type(soup)
# Out:
# None
# bs4.BeautifulSoup

# %%
table = soup.findAll('body')[0]
table
# Out:
# <body class="fixed" id="styleguide-v2">
# <script>
#     if (typeof uet == 'function') {
#       uet("bb");
#     }
# </script>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_body_delivery_started');
#     }
#   </script>
# <script>
#     if (typeof uet == 'function') {
#       uet("ns");
#     }
# </script>
# <style data-styled="FrFKl duAiCh kaQvFj kVaXNT juLXcx jfMlOM kSadNP gLdsIb cdGkjh ekTxdF hZgFLX gnIbsc kNsdJT drAwVR Nynko gWMKkS enRaDF iSwlYb dTOrsx iXmvCw fzXEIh" data-styled-version="4.3.2">
# /* sc-component-id: sc-bdVaJa */
# ...

# %%
table.findAll('h3')[0].findAll('a')[0].contents[0]
# Out:
# 'Avengers: Endgame'

# %%
table.findAll('p')[4].findAll('span')[4].contents[0].string.strip()
# Out:
# 'Action, Adventure, Sci-Fi'

# %%
table.findAll('p')[0].findAll('span')[0].contents[0]
# Out:
# 'PG-13'

# %%
table.findAll('h3')[1].findAll('a')[0].contents[0]
# Out:
# 'Avengers: Infinity War'

# %%
table.findAll('p')[8].findAll('span')[4].contents[0].string.strip()
# Out:
# 'Animation, Action, Adventure'

# %%
table.findAll('p')[7].findAll('span')[4].contents[0]
# Out:
# '$678.82M'

# %%
movie_names = []
page1 = list(range(50))
for movie in page1:
    movie_names.append(table.findAll('h3')[movie].findAll('a')[0].contents[0])

# %%
movie_genres = []
page1 = list(range(50))
x=0
for movie in page1:
    movie_genres.append(table.findAll('p')[x].findAll('span')[4].contents[0].string.strip())
    x += 4
    continue

# %%
len(movie_names)
# Out:
# 50

# %%
movie_gross = []
page1 = list(range(50))
x=3
for movie in page1:
    movie_gross.append(table.findAll('p')[x].findAll('span')[4].contents[0])
    x += 4
    continue

# %%
len(movie_gross)
# Out:
# 50

# %%
movie_ratings = []
page1 = list(range(50))
x=0
for movie in page1:
    movie_ratings.append(table.findAll('p')[x].findAll('span')[0].contents[0])
    x += 4
    continue

# %%
movie_ratings
# Out:
# ['PG-13',
#  'PG',
#  'G',
#  'PG-13',
#  'PG-13',
#  'PG',
#  'R',
#  'R',
#  'R',
#  'R',
#  'PG-13',
#  'PG',
#  'PG',
#  'PG',
#  'PG-13',
#  'R',
#  'PG',
#  'PG-13',
#  'PG-13',
#  'PG',
#  'R',
#  'PG-13',
#  'R',
#  'PG-13',
#  'R',
#  'PG-13',
#  'PG-13',
#  'R',
#  'R',
#  'PG-13',
#  'PG-13',
#  'PG-13',
#  'PG',
#  'R',
#  'R',
#  'R',
#  'PG-13',
#  'PG-13',
#  'R',
#  'PG',
#  'PG',
#  'PG',
#  'PG-13',
#  'R',
#  'PG',
#  'PG',
#  'PG-13',
#  'PG-13',
#  'PG-13',
#  'R']

# %%
moviedf2019 = pd.DataFrame()

# %%
moviedf2019['name'] = movie_names

# %%
moviedf2019['genre'] = movie_genres

# %%
moviedf2019['gross'] = movie_gross

# %%
moviedf2019['rating'] = movie_ratings

# %%
moviedf2019['release_year'] = 2019

# %%
moviedf2019
# Out:
#                                           name                         genre  \
# 0                            Avengers: Endgame      Action, Adventure, Drama
# 1                                The Lion King   Animation, Adventure, Drama
# 2                                  Toy Story 4  Animation, Adventure, Comedy
# 3                               Captain Marvel     Action, Adventure, Sci-Fi
# 4                    Spider-Man: Far from Home     Action, Adventure, Sci-Fi
# 5                                      Aladdin    Adventure, Family, Fantasy
# 6                               It Chapter Two        Drama, Fantasy, Horror
# 7                                        Joker        Crime, Drama, Thriller
# 8                                           Us     Horror, Mystery, Thriller
# 9            John Wick: Chapter 3 - Parabellum       Action, Crime, Thriller
# 10       Fast & Furious Presents: Hobbs & Shaw             Action, Adventure
# ...

# %%
moviedf15_19 = pd.concat([fouryeardf, moviedf2019])

# %%
moviedf15_19
# Out:
#                               name                         genre     gross  \
# 0                    Black Panther     Action, Adventure, Sci-Fi  $700.06M
# 1           Avengers: Infinity War     Action, Adventure, Sci-Fi  $678.82M
# 2                    Incredibles 2  Animation, Action, Adventure  $608.58M
# 3   Jurassic World: Fallen Kingdom     Action, Adventure, Sci-Fi  $417.72M
# 4                          Aquaman    Action, Adventure, Fantasy  $335.06M
# ..                             ...                           ...       ...
# 45    Maleficent: Mistress of Evil    Adventure, Family, Fantasy   $36.95M
# 46                    The Intruder        Drama, Horror, Mystery   $35.42M
# 47                      The Hustle                 Comedy, Crime   $35.42M
# 48                        Ad Astra     Adventure, Drama, Mystery   $35.40M
# 49                    Cold Pursuit          Action, Crime, Drama   $32.14M
#
#    rating  release_year
# 0   PG-13          2018
# ...
